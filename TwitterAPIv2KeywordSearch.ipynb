# %%
# import libraries
import pandas as pd
import requests
import os
import json
import csv
import time
from dotenv import load_dotenv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata

# %%
# load environment variables in the .env file in the same directory
# You need to have .env file and set BEARER_TOKEN='PUT TWITTER BEARER TOKEN HERE'
load_dotenv()
# Out:
# True

# %%
# set headers for API request
def create_headers():
    bearer_token = os.environ.get("BEARER_TOKEN")
    return {"Authorization": "Bearer {}".format(bearer_token)}

# %%
# Function to generate URL and Parameters for API call
def create_url(keyword, start_time, end_time, max_results=10):
    
    search_url = "https://api.twitter.com/2/tweets/search/recent"
    
    query_params = {
        'query': keyword,
        'start_time': start_time,
        'end_time': end_time,
        'max_results': max_results,
        'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
        'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
        'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
        'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
        #'place.fields': 'full_name,country',
        'next_token':{}
    }
    return (search_url, query_params)

# %%
# Function to make GET request to desired endpoint
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token
    response = requests.request("GET", url, params=params, headers=headers)
        
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
#Inputs for the request
bearer_token = os.environ.get("BEARER_TOKEN")
headers = create_headers()
keyword = "ウーバーイーツ"
start_time = "2021-12-26T00:00:00.000Z"
end_time = "2021-12-26T00:00:30:00.000Z"
max_results = 15

# %%
# Call API
url = create_url(keyword, start_time, end_time, max_results)
json_response = connect_to_endpoint(url[0], headers, url[1])
# Out:
# Endpoint Response Code: 401
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-33-38e1df6eef73> in <module>()
#       1 # Call API
#       2 url = create_url(keyword, start_time, end_time, max_results)
# ----> 3 json_response = connect_to_endpoint(url[0], headers, url[1])
#
# <ipython-input-5-2478f5c5272b> in connect_to_endpoint(url, headers, params, next_token)
#       6     print("Endpoint Response Code: " + str(response.status_code))
#       7     if response.status_code != 200:
# ----> 8         raise Exception(response.status_code, response.text)
#       9     return response.json()
#
# Exception: (401, '{\n  "title": "Unauthorized",\n  "type": "about:blank",\n  "status": 401,\n  "detail": "Unauthorized"\n}')

# %%
# Create output csv file
csvFile = open("result.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'geo', 'id','lang', 'like_count', 'quote_count', 'reply_count','retweet_count','source','tweet'])
csvFile.close()

# %%
def append_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that
        
        
        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 3. Geolocation
        if ('geo' in tweet):   
            geo = tweet['geo']['place_id']
        else:
            geo = " "
        
        # 4. Tweet ID
        tweet_id = tweet['id']
        
        # 5. Language
        lang = tweet['lang']

        # 6. Tweet metrics
        retweet_count = tweet['public_metrics']['retweet_count']
        reply_count = tweet['public_metrics']['reply_count']
        like_count = tweet['public_metrics']['like_count']
        quote_count = tweet['public_metrics']['quote_count']

        # 7. source
        source = tweet['source']
        
        # 8. Tweet text
        text = tweet['text']
        
        # Assemble all data in a list
        #res = [tweet_id, text]
        res = [author_id, created_at, geo, tweet_id, lang, like_count, quote_count, reply_count, retweet_count, source, text]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)

# %%
# Pagination for tweets over results > 100
total_tweets = 0
max_results = 100

count = 0
max_count = 100
flag = True
next_token = None


while flag:
    if count >= max_count:
        break
    print("-----------------")
    print("Token: ", next_token)
    print(count)
    url = create_url(keyword, start_time, end_time, max_results)
    json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
    result_count = json_response['meta']['result_count']
    print("INITIAL")
    
    if 'next_token' in json_response['meta']:
        # save the token to use for next call
        next_token = json_response['meta']['next_token']
        print("Next Token: ", next_token)
        if result_count is not None and result_count > 0 and next_token is not None:
            append_to_csv(json_response, "result.csv")
            print("TYPE 1")
       
            total_tweets += result_count
            print("Total # of Tweets added: ", total_tweets)
            print("-----------------")
            time.sleep(5)
    # if no next token exists
    else:
        if result_count is not None and result_count > 0:
            print("-----------------")
            append_to_csv(json_response, "result.csv")
            print("TYPE 2")
            total_tweets += result_count
            print("Total # of Tweets added: ", total_tweets)
            print("-----------------")
            time.sleep(5)
            
        flag = False
        next_token = None
    time.sleep(5)
print("Total number of results: " , total_tweets)
# Out:
# -----------------
# Token:  None
# 0
# Endpoint Response Code: 200
# INITIAL
# Next Token:  b26v89c19zqg8o3fpe1715j0vj89fojfl3yxvylm3aet9
# # of Tweets added from this response:  100
# TYPE 1
# Total # of Tweets added:  100
# -----------------
# -----------------
# Token:  b26v89c19zqg8o3fpe1715j0vj89fojfl3yxvylm3aet9
# 0
# Endpoint Response Code: 200
# INITIAL
# -----------------
# # of Tweets added from this response:  28
# TYPE 2
# Total # of Tweets added:  128
# -----------------
# Total number of results:  128

# %%
pd.read_csv("result.csv")
# Out:
#      1392367096055488515  2021-12-26 00:29:52+00:00     1474900232475492357  \
# 0    1411142914663600129  2021-12-26 00:29:38+00:00     1474900174115950599
# 1    1357545037119119360  2021-12-26 00:29:30+00:00     1474900140397940740
# 2               82841493  2021-12-26 00:28:59+00:00     1474900008575340547
# 3               72681507  2021-12-26 00:28:47+00:00     1474899961804648448
# 4    1455881867111002119  2021-12-26 00:28:32+00:00     1474899896541282304
# 5    1451181307183046660  2021-12-26 00:28:30+00:00     1474899889662611457
# 6             1613287687  2021-12-26 00:28:30+00:00     1474899887942946820
# 7    1244066887870234624  2021-12-26 00:28:23+00:00     1474899859895644160
# 8    1256740634326515712  2021-12-26 00:28:11+00:00     1474899810474139650
# 9    1401894100412952578  2021-12-26 00:28:07+00:00     1474899792212144128
# 10   1402258485186904071  2021-12-26 00:28:05+00:00     1474899784935026689
# 11   1190241116802564098  2021-12-26 00:28:02+00:00     1474899771144142853
# 12   1253972742354857984  2021-12-26 00:27:59+00:00     1474899760494833666
# 13            1569312728  2021-12-26 00:27:42+00:00     1474899686440181761
# 14            3747080772  2021-12-26 00:27:27+00:00     1474899626155442176
# 15   1229789407512645632  2021-12-26 00:27:16+00:00     1474899579409952768
# 16   1033507722518360064  2021-12-26 00:26:17+00:00     1474899331509817345
# 17   1435861142572711938  2021-12-26 00:26:04+00:00     1474899278279888897
# 18   1152218452641353728  2021-12-26 00:25:49+00:00     1474899212081201156
# 19            3605198473  2021-12-26 00:25:31+00:00     1474899139138056192
# 20   1276152051714732032  2021-12-26 00:24:56+00:00     1474898992287055873
# 21   1473923108252037121  2021-12-26 00:24:42+00:00     1474898931238969349
# 22   1253312669353795587  2021-12-26 00:23:58+00:00     1474898749617242114
# 23              38185207  2021-12-26 00:23:43+00:00     1474898687264718852
# 24   1347943433667702789  2021-12-26 00:23:41+00:00     1474898676330135556
# 25   1227581055365894144  2021-12-26 00:23:35+00:00     1474898653718642690
# 26   1244066887870234624  2021-12-26 00:23:33+00:00     1474898643048349700
# 27   1455881867111002119  2021-12-26 00:23:31+00:00     1474898635729272833
# 28   1282954868487892992  2021-12-26 00:23:21+00:00     1474898592637026307
# 29   1400774484932497409  2021-12-26 00:23:09+00:00     1474898543274250243
# ..                   ...                        ... ..                  ...
# 97   1140985122897797120  2021-12-26 00:07:35+00:00     1474894624364068866
# 98   1259870301396983810  2021-12-26 00:07:20+00:00     1474894560220545024
# 99   1304682462669225985  2021-12-26 00:07:11+00:00     1474894525210701824
# 100           2397826308  2021-12-26 00:07:09+00:00     1474894516817895424
# 101  1149832391717879810  2021-12-26 00:07:08+00:00     1474894512099323907
# 102  1243055058964459520  2021-12-26 00:07:04+00:00     1474894494202236934
# 103  1304656566503665665  2021-12-26 00:06:56+00:00     1474894460714893314
# 104  1160822009401528321  2021-12-26 00:06:41+00:00     1474894400346271747
# 105  1213392755298144256  2021-12-26 00:06:00+00:00     1474894227637403651
# 106  1125735864745639936  2021-12-26 00:05:51+00:00     1474894190794657794
# 107  1112281799726518272  2021-12-26 00:05:33+00:00     1474894114726776833
# 108  1225727236902289408  2021-12-26 00:05:30+00:00     1474894101137227777
# 109  1282954868487892992  2021-12-26 00:05:30+00:00     1474894100738764800
# 110  1191210129003143169  2021-12-26 00:04:46+00:00     1474893914805276673
# 111  1368038555402919937  2021-12-26 00:04:28+00:00     1474893838871588864
# 112  1182568151231299585  2021-12-26 00:04:26+00:00     1474893830998867974
# 113  1244066887870234624  2021-12-26 00:04:17+00:00     1474893793438879745
# 114  1204754785510887424  2021-12-26 00:04:01+00:00     1474893725973512197
# 115  1168441900543561728  2021-12-26 00:03:52+00:00     1474893688459661312
# 116   887661984786796545  2021-12-26 00:03:51+00:00     1474893683816566789
# 117  1455881867111002119  2021-12-26 00:03:48+00:00     1474893672038940679
# 118  1120699248637427713  2021-12-26 00:03:25+00:00     1474893576417198081
# 119  1396980868783038464  2021-12-26 00:03:24+00:00     1474893573544091648
# 120  1413027065981411329  2021-12-26 00:03:13+00:00     1474893526542745601
# 121  1440812480817553412  2021-12-26 00:02:31+00:00     1474893349987536897
# 122  1218377747027775488  2021-12-26 00:02:17+00:00     1474893291003203585
# 123  1112281799726518272  2021-12-26 00:00:59+00:00     1474892965097394178
# 124   832083067393093632  2021-12-26 00:00:47+00:00     1474892913578770433
# 125  1005424547124817920  2021-12-26 00:00:34+00:00     1474892860042399746
# 126  1186288161443368960  2021-12-26 00:00:13+00:00     1474892772469805056
#
#      ja  0  0.1  0.2  0.3            Botbird tweets  \
# 0    ja  0    0    0    0            Botbird tweets
# 1    ja  0    0    0    0            Botbird tweets
# 2    ja  0    0    0    0  get-access-token-rickbox
# 3    ja  0    0    0   59           Twitter Web App
# 4    ja  0    0    0    0              twittbot.net
# 5    ja  0    0    0    0              twittbot.net
# 6    ja  0    0    0    0              twittbot.net
# 7    ja  0    0    0    0              twittbot.net
# 8    ja  0    0    0    0              twittbot.net
# 9    ja  0    0    0    0              twittbot.net
# 10   ja  0    0    0    0              twittbot.net
# 11   ja  0    0    0    0              twittbot.net
# 12   ja  0    0    0    0              twittbot.net
# 13   ja  0    0    0   59       Twitter for Android
# 14   ja  0    0    0    7        Twitter for iPhone
# 15   ja  0    0    0   83           Twitter Web App
# 16   ja  0    0    0    0              twittbot.net
# 17   ja  0    0    0    0           Twitter for Mac
# 18   ja  0    0    0    0              twittbot.net
# 19   ja  0    0    0    0              twittbot.net
# 20   ja  0    0    0    0              twittbot.net
# 21   ja  1    0    0    0        Twitter for iPhone
# 22   ja  0    0    0    0              twittbot.net
# 23   ja  0    0    0   59           Twitter Web App
# 24   ja  0    0    0    0              twittbot.net
# 25   ja  0    0    0    0              twittbot.net
# 26   ja  0    0    0    0              twittbot.net
# 27   ja  0    0    0    0              twittbot.net
# 28   ja  1    0    0    0              twittbot.net
# 29   ja  0    0    0    0              twittbot.net
# ..   .. ..  ...  ...  ...                       ...
# 97   ja  0    0    0    0              twittbot.net
# 98   ja  0    0    0    0              twittbot.net
# 99   ja  0    0    0    0              twittbot.net
# 100  ja  0    0    0   21          Twitter for iPad
# 101  ja  0    0    0    0              twittbot.net
# 102  ja  0    0    0    0              twittbot.net
# 103  ja  0    0    0    0              twittbot.net
# 104  ja  0    0    1    0           Twitter Web App
# 105  ja  0    0    0    0              twittbot.net
# 106  ja  0    0    0    0              twittbot.net
# 107  ja  0    0    0    0              twittbot.net
# 108  ja  0    0    0    0              twittbot.net
# 109  ja  0    0    0    0              twittbot.net
# 110  ja  0    0    0    0              twittbot.net
# 111  ja  0    0    0   36       Twitter for Android
# 112  ja  0    0    0    0              twittbot.net
# 113  ja  0    0    0    0              twittbot.net
# 114  ja  0    0    0   83       Twitter for Android
# 115  ja  0    0    0    0              twittbot.net
# 116  ja  0    0    0    0              twittbot.net
# 117  ja  0    0    0    0              twittbot.net
# 118  ja  0    0    0    0              twittbot.net
# 119  ja  0    0    0    0              twittbot.net
# 120  ja  0    0    0    0              twittbot.net
# 121  ja  0    0    0    0            Botbird tweets
# 122  ja  2    0    0    0        Twitter for iPhone
# 123  ja  0    0    0    0              twittbot.net
# 124  ja  0    0    0    6        Twitter for iPhone
# 125  ja  0    0    0    0            Botbird tweets
# 126  ja  0    0    0   83       Twitter for Android
#
#     配達の単価が下がったって聞きましたけど、大丈夫ですか？\nもし貴方が介護の資格をもっていてデリバリーでは収入が安定しないならもう１件、訪問介護で働きません？堺市の平均時給より高いですよ、うち\nhttps://t.co/pD7EBHLyne\n\n#配達員 #ウーバーイーツ #介護 #大阪　#ヘルパー募集
# 0    ウーバーイーツで初回配達＆登録をする人はいませんか？\n招待コード【pbyh6i】を入力すれ...
# 1    お腹が空いていませんか？\n\n【eats-ebbk6r】 \n\nこちらのコード使うと、ウ...
# 2    2500円引き♪\n\n【eats-ckvsvberue】\n\n上記プロモーションコード使...
# 3    RT @oscarnoyukue: 「東京自転車節」を観る。コロナ禍に上京してウーバーイーツ...
# 4    好きな時間で自由に休憩〜ウーバーイーツ配達員を始める方！招待コード「ag31nnsvpvfe...
# 5    食欲の冬！ウーバーイーツデビュー！！\nUber Eats初回限定クーポン発行中！\n\n✅...
# 6    【先着5枚】ｷﾀーー(ﾟ∀ﾟ)ーー！\nUber Eatsの初回注文↓のコードで4000円割...
# 7    か\n友達招待コード クーポン 割引券\nプロモーションコード\nメルカリ「FPXFFY」\...
# 8    検索から見つけてくださりありがとうございます☆\n以下、私の招待コードです！\n\nウーバー...
# 9    ・UberEats限定クーポン2021年6月最新版・\n\n【eats-8yi0a9ufx1...
# 10   ・2021年6月最新版 UberEats限定クーポン・\n\n【eats-8yi0a9ufx...
# 11   ウーバーイーツ 2000-2250円のクーポンプロモーションコード\n新規登録限定、！\n\...
# 12   ウーバーイーツで初回限定で使えるプロモーションコード『eats-kp64ld』を配布していま...
# 13   RT @oscarnoyukue: 「東京自転車節」を観る。コロナ禍に上京してウーバーイーツ...
# 14   RT @toben_pferd: 『こんばんはー！！\nウーバーイーツですー！！！』 htt...
# 15   RT @etI5ZwHIhGTu3vO: 【Ubereats無料クーポンコード】\n\n初回...
# 16   ＊ 【UberEats割引クーポン 】 ウーバーイーツ初めて注文する方は、注文画面でプロモー...
# 17   ウーバーイーツが気持ち悪いんだけどお前ら普通に頼めるの？ https://t.co/DSLP...
# 18   ウーバーイーツは玄関前に置く非対面配達も選べます(*ﾟ∀ﾟ*)\nこちらは最新クーポンです♪...
# 19   期間限定 ウーバーイーツ 初めて登録の際注文画面でコード入力すると最大で2500円無料です。...
# 20   【ウーバーイーツ】初回注文クーポン　　1800円off!【eats-dwv9k58nue】ご...
# 21   日本のウーバーイーツやネットスーパー、Amazonフレッシュなどの、どこが安くて早いとかクー...
# 22   ただいまウーバーイーツ初めて頼む方が1200円割引されるクーポン配布してます！\neats-...
# 23   RT @oscarnoyukue: 「東京自転車節」を観る。コロナ禍に上京してウーバーイーツ...
# 24   ・2021年1月最新版・\n\nウーバーイーツクーポンコード\n\neats-4kub32\...
# 25   uber eats配達を始たい方に速報②⑤\nウーバーイーツの配達員になれば\n令和の今だけ...
# 26   お\n友達招待コード クーポン 割引券\nプロモーションコード\nメルカリ「FPXFFY」\...
# 27   らくらく〜ウーバーイーツ配達員を始める方！招待コード「ag31nnsvpvfe」と入力！  ...
# 28   ♢配達員が不足しがちな下記エリアにて、ウーバーイーツ配達員 を募集します  京都エリア、兵庫...
# 29   ・2021年6月最新版UberEats限定クーポン・\n\n【eats-8yi0a9ufx1...
# ..                                                 ...
# 97   【eats-r7ovgs】ウーバーイーツ/uber eatsのクーポンコードで合計3000円...
# 98   デリバリーを便利におトクに利用しよう！\n\n期間限定コード　【eats-4et27r】\n...
# 99   ⭐️超お得情報⭐️\nUberEats(ウーバーイーツ)の新規登録クーポン発行中✨\n注文時...
# 100  RT @k2gtr: 「隠れ宅配」誰が運ぶ　Amazonの荷物、半数が統計外: 日本経済新聞...
# 101  『ウーバーイーツで収入アップさせたい！』\n\nという方に向け、これだけ押さえておけば大丈夫...
# 102  下記のサービスをお得に利用するには\n以下のクーポンコードを入力！\nメルカリ\nKKYRD...
# 103  uber eats（ウーバーイーツ）が\n青梅市でも♪\n\n気になる配達エリアやお得なクー...
# 104  2日ほど前にウーバーイーツに登録しました。\n「アカウントの準備をしています」からずっと変わ...
# 105  ウーバーイーツ 初めて登録の際注文画面でコード入力すると最大で2500円無料です\n注文画面...
# 106  [2021年12月更新　最新情報]\n初回限定で使用できるクーポンです。\n下記プロモーショ...
# 107  Ubereats ウーバーイーツの割引クーポン配布中♪♪\n\nプロモーションコード入力で、...
# 108  現金当日2万円手渡しでゲットしたぞ!!Uber Eats最高すぎる!!\n\nウーバーイーツ...
# 109  配達員不足の次のエリアで、ウーバーイーツ配達員を募集中です！\n\n奈良、久留米、高松、松山...
# 110  [2021年12月更新　最新情報]\n1800yen Off UberEats Coupon...
# 111  RT @BN_McBa: 俺昨日ウーバーイーツ頼んでから4時間後に来たんだけど、冷静に考えた...
# 112  ⭐️期間限定⭐️\nUberEats(ウーバーイーツ)の新規登録時にクーポンコードを入力する...
# 113  あ\n友達招待コード クーポン 割引券\nプロモーションコード\nメルカリ「FPXFFY」\...
# 114  RT @etI5ZwHIhGTu3vO: 【Ubereats無料クーポンコード】\n\n初回...
# 115  [2021年12月更新　最新情報]\n何食べよ\nウーバーイーツ\n便利だな\n\n初回限定...
# 116  \ 2021年最新版！/ ウーバーイーツを初めて使う方限定のクーポン！ 【eats-qg9y...
# 117  時間は自由〜ウーバーイーツ配達は如何でしょうか！招待コード「ag31nnsvpvfe」と入力...
# 118  【Uber Eats(ウーバーイーツ)kindle本リリース情報！】\n\n☆こんな人にオス...
# 119  ・UberEats限定クーポン2021年5月最新版・\n\n【eats-8yi0a9ufx1...
# 120  ウーバーイーツ初回1800円分無料！プロモーションコード：eats-1s9t6a3ws8 　...
# 121  おっす書いときます\nウーバーイーツ（UberEats）の配達員の登録の招待コード（紹介コー...
# 122             @shinodayuh ウーバーイーツが令和で一番イケてるテックですからねw
# 123  Ubereats ウーバーイーツの割引クーポン配布中です‼︎\n\nプロモーションコード入力...
# 124  RT @jikiya_jp: 自起屋のUberEats大好評～😍\n\n牛サムギョプサル弁当...
# 125  紹介特典付きお得情報掲載中 ポイント活動リンク (ෆ`꒳´ෆ)\n\nGRL♡楽天リーベイツ...
# 126  RT @etI5ZwHIhGTu3vO: 【Ubereats無料クーポンコード】\n\n初回...
#
# [127 rows x 11 columns]
