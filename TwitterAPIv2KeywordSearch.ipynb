# %%
# import libraries
import pandas as pd
import requests
import os
import json
import csv
import time
from dotenv import load_dotenv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata

# %%
# load environment variables in the .env file in the same directory
# You need to have .env file and set BEARER_TOKEN='PUT TWITTER BEARER TOKEN HERE'
load_dotenv()
# Out:
# True

# %%
# set headers for API request
def create_headers():
    bearer_token = os.environ.get("BEARER_TOKEN")
    return {"Authorization": "Bearer {}".format(bearer_token)}

# %%
# Function to generate URL and Parameters for API call
def create_url(keyword, start_time, end_time, max_results=10):
    
    search_url = "https://api.twitter.com/2/tweets/search/recent"
    
    query_params = {
        'query': keyword,
        'start_time': start_time,
        'end_time': end_time,
        'max_results': max_results,
        'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
        'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
        'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
        'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
        #'place.fields': 'full_name,country',
        'next_token':{}
    }
    return (search_url, query_params)

# %%
# Function to make GET request to desired endpoint
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token
    response = requests.request("GET", url, params=params, headers=headers)
        
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
#Inputs for the request
bearer_token = os.environ.get("BEARER_TOKEN")
headers = create_headers()
keyword = "ウーバーイーツ"
start_time = "2021-12-26T00:00:00.000Z"
end_time = "2021-12-26T00:10:00.000Z"
max_results = 15

# %%
# Call API
url = create_url(keyword, start_time, end_time, max_results)
json_response = connect_to_endpoint(url[0], headers, url[1])
print("url0: ",url[0])
print("headers: ",headers)
print("url1: ",url[1])
# Out:
# Endpoint Response Code: 200
# url0:  https://api.twitter.com/2/tweets/search/recent
# headers:  {'Authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAAG51XQEAAAAAMcF6nznSVdDwCYaFEcArB%2BYZtvI%3Dei5Ub8zUyuqA05rY9Pne1KZAXV4vWctMFVXx0xjXZaWAQ8Q7EH'}
# url1:  {'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'start_time': '2021-12-26T00:00:00.000Z', 'end_time': '2021-12-26T00:10:00.000Z', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'next_token': None, 'max_results': 15, 'query': 'ウーバーイーツ', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'expansions': 'author_id,in_reply_to_user_id,geo.place_id'}

# %%
# Function to make actual API call
def make_request(headers):
    url = "https://api.twitter.com/2/tweets/search/recent"
    query_params = {
        'query': 'ウーバーイーツ',
        'start_time': "2021-12-26T00:00:00.000Z",
        'end_time': "2021-12-26T00:10:00.000Z",
        'max_results': 10,
        'place.fields': 'full_name,country',
        'next_token':{}
    }
    return requests.request("GET", url, params=query_params, headers=headers).json()
    
response = make_request(headers)
data = response['data']
meta = response['meta']

# %%
# Create output csv file
csvFile = open("result.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)

#Create headers for the data you want to save, in this example, we only want save these columns in our dataset
csvWriter.writerow(['author id', 'created_at', 'geo', 'id','lang', 'like_count', 'quote_count', 'reply_count','retweet_count','source','tweet'])
csvFile.close()

# %%
def append_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that
        
        
        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 3. Geolocation
        if ('geo' in tweet):   
            geo = tweet['geo']['place_id']
        else:
            geo = " "
        
        # 4. Tweet ID
        tweet_id = tweet['id']
        
        # 5. Language
        lang = tweet['lang']

        # 6. Tweet metrics
        retweet_count = tweet['public_metrics']['retweet_count']
        reply_count = tweet['public_metrics']['reply_count']
        like_count = tweet['public_metrics']['like_count']
        quote_count = tweet['public_metrics']['quote_count']

        # 7. source
        source = tweet['source']
        
        # 8. Tweet text
        text = tweet['text']
        
        # Assemble all data in a list
        #res = [tweet_id, text]
        res = [author_id, created_at, geo, tweet_id, lang, like_count, quote_count, reply_count, retweet_count, source, text]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)

# %%
# Converting to dataframe for friendly view
def make_df(response):
    return pd.DataFrame(response['data'])

# %%
# Pagination for tweets over results > 100
total_tweets = 0
max_results = 100

count = 0
max_count = 100
flag = True
next_token = None

while flag:
    if count >= max_count:
        break
    print("-----------------")
    print("Token: ", next_token)
    print(count)
    url = create_url(keyword, start_time, end_time, max_results)
    json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
    result_count = json_response['meta']['result_count']
    #count += 10
    
    if 'next_token' in json_response['meta']:
        # save the token to use for next call
        next_token = json_response['meta']['next_token']
        print("Next Token: ", next_token)
        if result_count is not None and result_count > 0 and next_token is not None:
            append_to_csv(json_response, "result.csv")
            df = make_df(json_response)
           # count += 10
            total_tweets += result_count
            print("Total # of Tweets added: ", total_tweets)
            print("-----------------")
            time.sleep(5)
    # if no next token exists
    else:
        if result_count is not None and result_count > 0:
            print("-----------------")
            append_to_csv(json_response, "result.csv")
            df = make_df(json_response)
           # count += 10
            total_tweets += result_count
            print("Total # of Tweets added: ", total_tweets)
            print("-----------------")
            time.sleep(5)
            
        flag = False
        next_token = None
    time.sleep(5)
print("Total number of results: " , total_tweets)
df
# Out:
# -----------------
# Token:  None
# 0
# Endpoint Response Code: 200
# -----------------
# # of Tweets added from this response:  46
# Total # of Tweets added:  46
# -----------------
# Total number of results:  46
#               author_id      conversation_id                created_at  \
# 0   1369942870136741894  1474893749155250176  2021-12-26T00:09:47.000Z
# 1             134317962  1474895156386349058  2021-12-26T00:09:42.000Z
# 2    995834500687872001  1474894978664960002  2021-12-26T00:08:59.000Z
# 3   1347927411107614720  1474894922939781122  2021-12-26T00:08:46.000Z
# 4   1343587218028331008  1474894889238556674  2021-12-26T00:08:38.000Z
# 5   1244066887870234624  1474894868711624705  2021-12-26T00:08:33.000Z
# 6   1196700167371550720  1474894858951307267  2021-12-26T00:08:31.000Z
# 7   1455881867111002119  1474894854866243584  2021-12-26T00:08:30.000Z
# 8   1451181307183046660  1474894845227696129  2021-12-26T00:08:27.000Z
# 9   1282954868487892992  1474894844657270787  2021-12-26T00:08:27.000Z
# 10  1281726604704534529  1474894828186091521  2021-12-26T00:08:23.000Z
# 11  1287132390905622529  1474894796225671172  2021-12-26T00:08:16.000Z
# 12  1362047530377252864  1474894788432642049  2021-12-26T00:08:14.000Z
# 13  1214936526712270848  1474894781528809477  2021-12-26T00:08:12.000Z
# 14            106189091  1474894751958990853  2021-12-26T00:08:05.000Z
# 15  1299896389707599872  1474894655880052737  2021-12-26T00:07:42.000Z
# 16  1140985122897797120  1474894624364068866  2021-12-26T00:07:35.000Z
# 17  1259870301396983810  1474894560220545024  2021-12-26T00:07:20.000Z
# 18  1304682462669225985  1474894525210701824  2021-12-26T00:07:11.000Z
# 19           2397826308  1474894516817895424  2021-12-26T00:07:09.000Z
# 20  1149832391717879810  1474894512099323907  2021-12-26T00:07:08.000Z
# 21  1243055058964459520  1474894494202236934  2021-12-26T00:07:04.000Z
# 22  1304656566503665665  1474894460714893314  2021-12-26T00:06:56.000Z
# 23  1160822009401528321  1474894400346271747  2021-12-26T00:06:41.000Z
# 24  1213392755298144256  1474894227637403651  2021-12-26T00:06:00.000Z
# 25  1125735864745639936  1474894190794657794  2021-12-26T00:05:51.000Z
# 26  1112281799726518272  1474894114726776833  2021-12-26T00:05:33.000Z
# 27  1225727236902289408  1474894101137227777  2021-12-26T00:05:30.000Z
# 28  1282954868487892992  1474894100738764800  2021-12-26T00:05:30.000Z
# 29  1191210129003143169  1474893914805276673  2021-12-26T00:04:46.000Z
# 30  1368038555402919937  1474893838871588864  2021-12-26T00:04:28.000Z
# 31  1182568151231299585  1474893830998867974  2021-12-26T00:04:26.000Z
# 32  1244066887870234624  1474893793438879745  2021-12-26T00:04:17.000Z
# 33  1204754785510887424  1474893725973512197  2021-12-26T00:04:01.000Z
# 34  1168441900543561728  1474893688459661312  2021-12-26T00:03:52.000Z
# 35   887661984786796545  1474893683816566789  2021-12-26T00:03:51.000Z
# 36  1455881867111002119  1474893672038940679  2021-12-26T00:03:48.000Z
# 37  1120699248637427713  1474893576417198081  2021-12-26T00:03:25.000Z
# 38  1396980868783038464  1474893573544091648  2021-12-26T00:03:24.000Z
# 39  1413027065981411329  1474893526542745601  2021-12-26T00:03:13.000Z
# 40  1440812480817553412  1474893349987536897  2021-12-26T00:02:31.000Z
# 41  1218377747027775488  1474889548199264260  2021-12-26T00:02:17.000Z
# 42  1112281799726518272  1474892965097394178  2021-12-26T00:00:59.000Z
# 43   832083067393093632  1474892913578770433  2021-12-26T00:00:47.000Z
# 44  1005424547124817920  1474892860042399746  2021-12-26T00:00:34.000Z
# 45  1186288161443368960  1474892772469805056  2021-12-26T00:00:13.000Z
#
#                      id  in_reply_to_user_id lang  \
# 0   1474895179333406723  1399558730723729412   ja
# 1   1474895156386349058                  NaN   ja
# 2   1474894978664960002                  NaN   ja
# 3   1474894922939781122                  NaN   ja
# 4   1474894889238556674                  NaN   ja
# 5   1474894868711624705                  NaN   ja
# 6   1474894858951307267                  NaN   ja
# 7   1474894854866243584                  NaN   ja
# 8   1474894845227696129                  NaN   ja
# 9   1474894844657270787                  NaN   ja
# 10  1474894828186091521                  NaN   ja
# 11  1474894796225671172                  NaN   ja
# 12  1474894788432642049                  NaN   ja
# 13  1474894781528809477                  NaN   ja
# 14  1474894751958990853                  NaN   ja
# 15  1474894655880052737                  NaN   ja
# 16  1474894624364068866                  NaN   ja
# 17  1474894560220545024                  NaN   ja
# 18  1474894525210701824                  NaN   ja
# 19  1474894516817895424                  NaN   ja
# 20  1474894512099323907                  NaN   ja
# 21  1474894494202236934                  NaN   ja
# 22  1474894460714893314                  NaN   ja
# 23  1474894400346271747                  NaN   ja
# 24  1474894227637403651                  NaN   ja
# 25  1474894190794657794                  NaN   ja
# 26  1474894114726776833                  NaN   ja
# 27  1474894101137227777                  NaN   ja
# 28  1474894100738764800                  NaN   ja
# 29  1474893914805276673                  NaN   ja
# 30  1474893838871588864                  NaN   ja
# 31  1474893830998867974                  NaN   ja
# 32  1474893793438879745                  NaN   ja
# 33  1474893725973512197                  NaN   ja
# 34  1474893688459661312                  NaN   ja
# 35  1474893683816566789                  NaN   ja
# 36  1474893672038940679                  NaN   ja
# 37  1474893576417198081                  NaN   ja
# 38  1474893573544091648                  NaN   ja
# 39  1474893526542745601                  NaN   ja
# 40  1474893349987536897                  NaN   ja
# 41  1474893291003203585  1338666130773168128   ja
# 42  1474892965097394178                  NaN   ja
# 43  1474892913578770433                  NaN   ja
# 44  1474892860042399746                  NaN   ja
# 45  1474892772469805056                  NaN   ja
#
#                                        public_metrics  \
# 0   {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 1   {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 2   {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 3   {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 4   {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 5   {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 6   {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 7   {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 8   {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 9   {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 10  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 11  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 12  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 13  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 14  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 15  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 16  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 17  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 18  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 19  {'quote_count': 0, 'retweet_count': 21, 'reply...
# 20  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 21  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 22  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 23  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 24  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 25  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 26  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 27  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 28  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 29  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 30  {'quote_count': 0, 'retweet_count': 36, 'reply...
# 31  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 32  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 33  {'quote_count': 0, 'retweet_count': 83, 'reply...
# 34  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 35  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 36  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 37  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 38  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 39  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 40  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 41  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 42  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 43  {'quote_count': 0, 'retweet_count': 6, 'reply_...
# 44  {'quote_count': 0, 'retweet_count': 0, 'reply_...
# 45  {'quote_count': 0, 'retweet_count': 83, 'reply...
#
#                                     referenced_tweets reply_settings  \
# 0   [{'type': 'replied_to', 'id': '147489374915525...       everyone
# 1                                                 NaN       everyone
# 2                                                 NaN       everyone
# 3                                                 NaN       everyone
# 4                                                 NaN       everyone
# 5                                                 NaN       everyone
# 6                                                 NaN       everyone
# 7                                                 NaN       everyone
# 8                                                 NaN       everyone
# 9                                                 NaN       everyone
# 10                                                NaN       everyone
# 11                                                NaN       everyone
# 12                                                NaN       everyone
# 13                                                NaN       everyone
# 14                                                NaN       everyone
# 15                                                NaN       everyone
# 16                                                NaN       everyone
# 17                                                NaN       everyone
# 18                                                NaN       everyone
# 19  [{'type': 'retweeted', 'id': '1474756786171580...       everyone
# 20                                                NaN       everyone
# 21                                                NaN       everyone
# 22                                                NaN       everyone
# 23                                                NaN       everyone
# 24                                                NaN       everyone
# 25                                                NaN       everyone
# 26                                                NaN       everyone
# 27                                                NaN       everyone
# 28                                                NaN       everyone
# 29                                                NaN       everyone
# 30  [{'type': 'retweeted', 'id': '1474620525955919...       everyone
# 31                                                NaN       everyone
# 32                                                NaN       everyone
# 33  [{'type': 'retweeted', 'id': '1474743058558496...       everyone
# 34                                                NaN       everyone
# 35                                                NaN       everyone
# 36                                                NaN       everyone
# 37                                                NaN       everyone
# 38                                                NaN       everyone
# 39                                                NaN       everyone
# 40                                                NaN       everyone
# 41  [{'type': 'replied_to', 'id': '147489246406262...       everyone
# 42                                                NaN       everyone
# 43  [{'type': 'retweeted', 'id': '1474568096098979...       everyone
# 44                                                NaN       everyone
# 45  [{'type': 'retweeted', 'id': '1474743058558496...       everyone
#
#                       source  \
# 0         Twitter for iPhone
# 1          feather for iOS
# 2            Twitter Web App
# 3               twittbot.net
# 4               twittbot.net
# 5               twittbot.net
# 6             Botbird tweets
# 7               twittbot.net
# 8               twittbot.net
# 9               twittbot.net
# 10            Botbird tweets
# 11              twittbot.net
# 12              twittbot.net
# 13              twittbot.net
# 14  get-access-token-rickbox
# 15              twittbot.net
# 16              twittbot.net
# 17              twittbot.net
# 18              twittbot.net
# 19          Twitter for iPad
# 20              twittbot.net
# 21              twittbot.net
# 22              twittbot.net
# 23           Twitter Web App
# 24              twittbot.net
# 25              twittbot.net
# 26              twittbot.net
# 27              twittbot.net
# 28              twittbot.net
# 29              twittbot.net
# 30       Twitter for Android
# 31              twittbot.net
# 32              twittbot.net
# 33       Twitter for Android
# 34              twittbot.net
# 35              twittbot.net
# 36              twittbot.net
# 37              twittbot.net
# 38              twittbot.net
# 39              twittbot.net
# 40            Botbird tweets
# 41        Twitter for iPhone
# 42              twittbot.net
# 43        Twitter for iPhone
# 44            Botbird tweets
# 45       Twitter for Android
#
#                                                  text
# 0           @87__riyu あらおいしそう😋\n\nウーバーイーツで届けてもらえるかな？😝
# 1      日曜日なのにこれ、ウーバーイーツもう駄目だろ https://t.co/ytq2yQYL7f
# 2   朝から編集が立て込んでいるのでウーバーイーツ頼もうかなと思ったけど…\n高くつくと思ったから...
# 3   ・2021年1月最新版・\n\neats-4kub32\n\n上記プロモーションコード使用で...
# 4   ♥【期間限定】UberEatsの高額割引クーポン配布♥ 初回注文時に利用可！ 会計の際にプロ...
# 5   い\n友達招待コード クーポン 割引券\nプロモーションコード\nメルカリ「FPXFFY」\...
# 6   甲府、鳥取、松江、福岡、福井でウーバーイーツ配達員になりたい人いませんか❓\n\n今なら2万...
# 7   主婦さんも〜ウーバーイーツ配達は如何でしょうか！招待コード「ag31nnsvpvfe」と入力...
# 8   食欲の冬！ウーバーイーツデビュー！！\nUber Eats初回限定クーポン発行中！\n\n✅...
# 9   ☆☆☆配達員が不足しがちな下記エリアにて、ウーバーイーツ配達員を募集します  広島市、仙台市...
# 10  UberEATS初回クーポン \n【eats-6u9028】    \n【初回注文限定】上記...
# 11  #ubereats配達員☆☆新規登録&amp;数回配達完了で、最大4万円ボーナス♪ ※エリア...
# 12  ・2021年2月最新版UberEats紹介コード・\n\nウーバーイーツ\n\n【eats-...
# 13  uber eats配達を始たい方に速報①⑥\nウーバーイーツの配達員に\n登録で最大15万円...
# 14  ウーバーイーツでお得にデリバリー\n今なら最大¥9000分のクーポンを配布中。\n\n[ea...
# 15  ⭐️超お得情報⭐️\nUberEats(ウーバーイーツ)の新規登録クーポン発行中✨\n注文時...
# 16  【eats-r7ovgs】ウーバーイーツ/uber eatsのクーポンコードで合計3000円...
# 17  デリバリーを便利におトクに利用しよう！\n\n期間限定コード　【eats-4et27r】\n...
# 18  ⭐️超お得情報⭐️\nUberEats(ウーバーイーツ)の新規登録クーポン発行中✨\n注文時...
# 19  RT @k2gtr: 「隠れ宅配」誰が運ぶ　Amazonの荷物、半数が統計外: 日本経済新聞...
# 20  『ウーバーイーツで収入アップさせたい！』\n\nという方に向け、これだけ押さえておけば大丈夫...
# 21  下記のサービスをお得に利用するには\n以下のクーポンコードを入力！\nメルカリ\nKKYRD...
# 22  uber eats（ウーバーイーツ）が\n青梅市でも♪\n\n気になる配達エリアやお得なクー...
# 23  2日ほど前にウーバーイーツに登録しました。\n「アカウントの準備をしています」からずっと変わ...
# 24  ウーバーイーツ 初めて登録の際注文画面でコード入力すると最大で2500円無料です\n注文画面...
# 25  [2021年12月更新　最新情報]\n初回限定で使用できるクーポンです。\n下記プロモーショ...
# 26  Ubereats ウーバーイーツの割引クーポン配布中♪♪\n\nプロモーションコード入力で、...
# 27  現金当日2万円手渡しでゲットしたぞ!!Uber Eats最高すぎる!!\n\nウーバーイーツ...
# 28  配達員不足の次のエリアで、ウーバーイーツ配達員を募集中です！\n\n奈良、久留米、高松、松山...
# 29  [2021年12月更新　最新情報]\n1800yen Off UberEats Coupon...
# 30  RT @BN_McBa: 俺昨日ウーバーイーツ頼んでから4時間後に来たんだけど、冷静に考えた...
# 31  ⭐️期間限定⭐️\nUberEats(ウーバーイーツ)の新規登録時にクーポンコードを入力する...
# 32  あ\n友達招待コード クーポン 割引券\nプロモーションコード\nメルカリ「FPXFFY」\...
# 33  RT @etI5ZwHIhGTu3vO: 【Ubereats無料クーポンコード】\n\n初回...
# 34  [2021年12月更新　最新情報]\n何食べよ\nウーバーイーツ\n便利だな\n\n初回限定...
# 35  \ 2021年最新版！/ ウーバーイーツを初めて使う方限定のクーポン！ 【eats-qg9y...
# 36  時間は自由〜ウーバーイーツ配達は如何でしょうか！招待コード「ag31nnsvpvfe」と入力...
# 37  【Uber Eats(ウーバーイーツ)kindle本リリース情報！】\n\n☆こんな人にオス...
# 38  ・UberEats限定クーポン2021年5月最新版・\n\n【eats-8yi0a9ufx1...
# 39  ウーバーイーツ初回1800円分無料！プロモーションコード：eats-1s9t6a3ws8 　...
# 40  おっす書いときます\nウーバーイーツ（UberEats）の配達員の登録の招待コード（紹介コー...
# 41             @shinodayuh ウーバーイーツが令和で一番イケてるテックですからねw
# 42  Ubereats ウーバーイーツの割引クーポン配布中です‼︎\n\nプロモーションコード入力...
# 43  RT @jikiya_jp: 自起屋のUberEats大好評～😍\n\n牛サムギョプサル弁当...
# 44  紹介特典付きお得情報掲載中 ポイント活動リンク (ෆ`꒳´ෆ)\n\nGRL♡楽天リーベイツ...
# 45  RT @etI5ZwHIhGTu3vO: 【Ubereats無料クーポンコード】\n\n初回...

# %%
df.to_csv('df.csv')
